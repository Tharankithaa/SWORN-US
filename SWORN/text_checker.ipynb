# %%
import sinlingua

# %%
from sinlingua.grammar_rule.grammar_rules import GrammarRules
from sinlingua.grammar_rule.rule_based_1 import FirstPerson
from sinlingua.grammar_rule.rule_based_2 import SecondPersonSingular
from sinlingua.grammar_rule.rule_based_3 import SecondPersonPlural
from sinlingua.grammar_rule.rule_based_4 import FourthPerson
from sinlingua.grammar_rule.rule_based_future_1 import FirstPersonFuture
from sinlingua.grammar_rule.rule_based_plural import PluralSubject
from sinlingua.grammar_rule.rule_based_plural_past import PluralSubjectPast
from sinlingua.grammar_rule.rule_based_singular import SingularSubject
from sinlingua.grammar_rule.rule_based_past_1 import PastFirstPerson
from sinlingua.grammar_rule.rule_based_past_2 import PastSecondPersonSingular
from sinlingua.grammar_rule.rule_based_past_3 import PastSecondPersonPlural
from sinlingua.grammar_rule.mask import PredictNoun

class GrammarMain:
    def __init__(self):
        pass

    @staticmethod
    def mapper(sentence: str):
       
        # First Person Rule
        first_person = FirstPerson()
        output1 = first_person.common_function(sentence)

        # Second Person Singular Rule
        second_person_singular = SecondPersonSingular()
        output2 = second_person_singular.common_function(sentence)

        # Second Person Plural Rule
        second_person_plural = SecondPersonPlural()
        output3 = second_person_plural.common_function(sentence)

        # First Person Future Rule
        first_person_future = FirstPersonFuture()
        output4 = first_person_future.common_function(sentence)

        # Plural Subject Rule
        plural_subject = PluralSubject()
        output5 = plural_subject.common_function(sentence)

        # Singular Subject Rule
        singular_subject = SingularSubject()
        output6 = singular_subject.common_function(sentence)

        # Past First Person Rule
        past_first_person = PastFirstPerson()
        output7 = past_first_person.common_function(sentence)

        # Past Second Person Singular Rule
        past_second_person_singular = PastSecondPersonSingular()
        output8 = past_second_person_singular.common_function(sentence)

        # Past Second Person Plural Rule
        past_second_person_plural = PastSecondPersonPlural()
        output9 = past_second_person_plural.common_function(sentence)

        # Predict Noun Rule
        noun_predict = PredictNoun()
        output10 = noun_predict.common_function(sentence)

        # Plural Subject Past Rule
        plural_subject_past = PluralSubjectPast()
        output11 = plural_subject_past.common_function(sentence)

        # Fourth Person Rule
        fourth_person = FourthPerson()
        output12 = fourth_person.common_function(sentence)

        # Combine all grammar rules
        grammar_rule = GrammarRules()
        return grammar_rule.apply_all_rules(
            [output1, output2, output3, output4, output5, output6, 
             output7, output8, output9, output10, output11, output12]
        )

# %%
# Import the GrammarMain class
from sinlingua.grammar_rule.grammar_main import GrammarMain

# Create an instance
obj = GrammarMain()

# Input sentence
text = "අපි පොසොන් පෝයට දන්සලක් සංවිධානය කරවා"

# Apply grammar correction
corrected_text = obj.mapper(sentence=text)

# Output the corrected sentence
print(corrected_text)
# Out:
# අපි පොසොන් පෝයට දන්සලක් සංවිධානය කරමු

# %%
import language_tool_python

class EnglishGrammarChecker:
    def __init__(self):
        # Use the remote LanguageTool server (no Java required)
        self.tool = language_tool_python.LanguageTool('en-US', remote_server='https://api.languagetool.org')

    def correct_text(self, sentence: str):
        """
        Corrects spelling and grammar errors in an English sentence using LanguageTool.

        '"""
        # Check for errors
        matches = self.tool.check(sentence)

        # Apply corrections
        corrected_sentence = language_tool_python.utils.correct(sentence, matches)

        return corrected_sentence

# Example usage
if __name__ == "__main__":
    checker = EnglishGrammarChecker()
    text = "tamil meaning."
    corrected_text = checker.correct_text(sentence=text)
    print("Original Sentence:", text)
    print("Corrected Sentence:", corrected_text)
# Out:
# Original Sentence: tamil meaning.
# Corrected Sentence: Tamil meaning.

# %%
import tamilinayavaani

# %%
tamilinayavaani.SpellChecker.REST_interface("ஓதால்")
# Out:
# (False, ['ஓதல்,ஓத்தாள்,ஓத்தால்'])

# %%
tamilinayavaani.SpellChecker.REST_interface("தமிலகம்")#பிழையானத
# Out:
# (False, ['தமிழகம்'])

# %% [markdown]
# Handwritten English

# %%
import requests

# API URL for the model
API_URL = "https://api-inference.huggingface.co/models/microsoft/trocr-base-handwritten"

# Your API token
headers = {"Authorization": "Bearer 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"}

def query(filename):
    """Send an image file to the Hugging Face API for OCR."""
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

# Example usage
output = query("hand eng.png")  
print(output)
# Out:
# [{'generated_text': 'Stories are born when people come together in relationship'}]

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/GnanaPrasath/ocr_tamil"
headers = {"Authorization": "Bearer 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"}

def query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

output = query("03.png")
print(output)
# Out:
# {'error': 'Unrecognized model in GnanaPrasath/ocr_tamil. Should have a `model_type` key in its config.json, or contain one of the following strings in its name: albert, align, altclip, audio-spectrogram-transformer, autoformer, bark, bart, beit, bert, bert-generation, big_bird, bigbird_pegasus, biogpt, bit, blenderbot, blenderbot-small, blip, blip-2, bloom, bridgetower, bros, camembert, canine, chameleon, chinese_clip, chinese_clip_vision_model, clap, clip, clip_text_model, clip_vision_model, clipseg, clvp, code_llama, codegen, cohere, conditional_detr, convbert, convnext, convnextv2, cpmant, ctrl, cvt, dac, data2vec-audio, data2vec-text, data2vec-vision, dbrx, deberta, deberta-v2, decision_transformer, deformable_detr, deit, depth_anything, deta, detr, dinat, dinov2, distilbert, donut-swin, dpr, dpt, efficientformer, efficientnet, electra, encodec, encoder-decoder, ernie, ernie_m, esm, falcon, falcon_mamba, fastspeech2_conformer, flaubert, flava, fnet, focalnet, fsmt, funnel, fuyu, 
# ...

# %%
from ocr_tamil.ocr import OCR
from IPython.display import Image

ocr = OCR(detect=False)

# %%
image_path = r"03.png"

Image(image_path,width=300, height=400)

# %%
ocr_detect_tamil = OCR(detect=True,lang=["tamil"],batch_size=128)
texts = ocr_detect_tamil.predict(image_path)
" ".join(texts[0])
# Out:
# 'நமது நாடு இந்தியா நாம் அணைனுடும் இந்தியர் குற்றது அளது கில்லாதது ஐடூ அளவு நடிது டூதசிய  மயில்'

# %%
import requests

# Hugging Face API URL and Authorization Token
API_URL = "https://api-inference.huggingface.co/models/facebook/mbart-large-50-many-to-many-mmt"
headers = {"Authorization": "Bearer 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"}  # Replace with your actual token

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

# Input text and language codes
input_text = "Hello, how are you ? ,  නුචර එළිය "  # Replace with your text
source_lang = "en_XX"  # English source language
target_lang = "ta_IN"  # Tamil target language (or "si_LK" for Sinhala)

# Query the API
output = query({
    "inputs": input_text,
    "parameters": {
        "src_lang": source_lang,  # Specify source language
        "tgt_lang": target_lang  # Specify target language
    }
})

# Display the output
print(output)
# Out:
# [{'translation_text': 'எப்படி? , නුචර එළිය'}]

# %%
import requests
from langdetect import detect

# Hugging Face API URL and Authorization Token
API_URL = "https://api-inference.huggingface.co/models/facebook/mbart-large-50-many-to-many-mmt"
headers = {"Authorization": "Bearer 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"}  # Replace with your token

# Function to query the translation model
def translate(text, src_lang, tgt_lang):
    payload = {
        "inputs": text,
        "parameters": {
            "src_lang": src_lang,
            "tgt_lang": tgt_lang
        }
    }
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

# Input text with mixed languages
input_text = "Hello, நான் தமிழில் பேசுகிறேன், නුචර එළිය"  # Mixed English and Tamil and sinhala to one language sinhala

# Split by punctuation marks to handle different languages
import re
segments = re.split(r'[,.!?;]', input_text)  # Split by punctuation marks

# Remove empty segments
segments = [segment.strip() for segment in segments if segment.strip()]

translations = []

for segment in segments:
    if len(segment) < 3:  # Skip very short segments
        continue
    
    try:
        detected_lang = detect(segment)  # Detect language
        if detected_lang == "en":
            src_lang = "en_XX"
        elif detected_lang == "ta":
            src_lang = "ta_IN"
        else:
            continue  # Skip unsupported languages

        # Translate each segment to Sinhala
        translated_segment = translate(segment, src_lang, "si_LK")
        
        # Debugging: Print the response structure
        print(f"Translated Segment Response: {translated_segment}")
        
        # Ensure we are appending the correct translation text
        if isinstance(translated_segment, list) and len(translated_segment) > 0:
            translations.append(translated_segment[0].get("translation_text", ""))
    except Exception as e:
        print(f"Error translating segment: {segment}, Error: {e}")

# Combine translated segments
output_text = " ".join(translations)
print(output_text)
# Out:
# Translated Segment Response: [{'translation_text': 'මම කතා කරනවා Tamil'}]
# Error translating segment: නුචර එළිය, Error: No features in text.
# මම කතා කරනවා Tamil

# %%
import requests
from langdetect import detect

# Hugging Face API URL and Authorization Token
API_URL = "https://api-inference.huggingface.co/models/facebook/mbart-large-50-many-to-many-mmt"
headers = {"Authorization": "Bearer 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"}  # Replace with your token

# Function to query the translation model
def translate(text, src_lang, tgt_lang):
    payload = {
        "inputs": text,
        "parameters": {
            "src_lang": src_lang,
            "tgt_lang": tgt_lang
        }
    }
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

# Input text with mixed languages
input_text = "Hello, நான் தமிழில் பேசுகிறேன், නුචර එළිය"  # Mixed English, Tamil, and Sinhala

# Detect the language of the entire input text
detected_lang = detect(input_text)  # Detect the overall language of the text

# Choose the target language based on detection
if detected_lang == "en":
    src_lang = "en_XX"
    tgt_lang = "si_LK"  # Translate to Sinhala
elif detected_lang == "ta":
    src_lang = "ta_IN"
    tgt_lang = "si_LK"  # Translate to Sinhala
elif detected_lang == "si":
    src_lang = "si_LK"
    tgt_lang = "en_XX"  # Translate to English
else:
    src_lang = "en_XX"  # Default to English if language detection fails
    tgt_lang = "si_LK"  # Translate to Sinhala

# Translate the entire input text to the target language
translated_text = translate(input_text, src_lang, tgt_lang)

# Debugging: Print the full response to check its structure
print(f"Translated Text Response: {translated_text}")

# Extract the translation text from the response
if isinstance(translated_text, list) and len(translated_text) > 0:
    output_text = translated_text[0].get("translation_text", "")
    print(f"Fully Translated Text: {output_text}")
else:
    print("Error: Translation failed.")
# Out:
# Translated Text Response: [{'translation_text': 'Hello, I am speaking Tamil.'}]
# Fully Translated Text: Hello, I am speaking Tamil.

# %%
from googletrans import Translator
import re

# Initialize the Google Translator
translator = Translator()

# Input text with mixed languages
input_text = "Hello, நான் தமிழில் பேசுகிறேன், නුචර එළිය"  # Mixed English, Tamil, and Sinhala

# Function to detect and translate the text
def translate_mixed_text(input_text):
    # Split the input text by punctuation marks to identify language segments
    segments = re.split(r'([,;.!?])', input_text)  # Split by punctuation marks while keeping the punctuation
    
    translated_segments = []
    
    for segment in segments:
        segment = segment.strip()
        
        if len(segment) < 2:  # Skip very short segments
            continue
        
        if re.search('[\u0D80-\u0DFF]', segment):  # Check if the segment contains Sinhala characters
            translated_segments.append(segment)  # Keep the Sinhala segment as is
        else:
            # Translate the non-Sinhala segments
            translated = translator.translate(segment, src='auto', dest='si')
            translated_segments.append(translated.text)
    
    # Combine the translated segments back together
    return ''.join(translated_segments)

# Translate the mixed input text
output_text = translate_mixed_text(input_text)

# Print the fully translated text
print(f"Translated Text: {output_text}")
# Out:
# Translated Text: ආයුබෝවන්මම දෙමළෙන් කතා කරනවානුචර එළිය

# %%
from googletrans import Translator
import re

# Initialize the Google Translator
translator = Translator()

# Input text with mixed languages
input_text = "Hello, நான் தமிழில் பேசுகிறேன், නුචර එළිය"  # Mixed English, Tamil, and Sinhala

# Function to detect and translate the text
def translate_mixed_text(input_text):
    # Split the input text by punctuation marks to identify language segments
    segments = re.split(r'([,;.!?])', input_text)  # Split by punctuation marks while keeping the punctuation
    
    translated_segments = []
    
    for segment in segments:
        segment = segment.strip()
        
        if len(segment) < 2:  # Skip very short segments
            continue
        
        if re.search('[\u0D80-\u0DFF]', segment):  # Check if the segment contains Sinhala characters
            translated_segments.append(segment)  # Keep the Sinhala segment as is
        else:
            # Translate the non-Sinhala segments
            translated = translator.translate(segment, src='auto', dest='ta')
            translated_segments.append(translated.text)
    
    # Combine the translated segments back together
    return ''.join(translated_segments)

# Translate the mixed input text
output_text = translate_mixed_text(input_text)

# Print the fully translated text
print(f"Translated Text: {output_text}")
# Out:
# Translated Text: வணக்கம்நான் தமிழில் பேசுகிறேன்නුචර එළිය

# %%
from googletrans import Translator
import re

# Initialize the Google Translator
translator = Translator()

# Input text with mixed languages
input_text = "Hello, நான் தமிழில் பேசுகிறேன், නුචර එළිය"  # Mixed English, Tamil, and Sinhala

# Function to detect and translate the text
def translate_mixed_text(input_text, target_language):
    # Split the input text by punctuation marks to identify language segments
    segments = re.split(r'([,;.!?])', input_text)  # Split by punctuation marks while keeping the punctuation
    
    translated_segments = []
    
    for segment in segments:
        segment = segment.strip()
        
        if len(segment) < 2:  # Skip very short segments
            continue
        
        if target_language == 'si' and re.search('[\u0D80-\u0DFF]', segment):  # Check Sinhala
            translated_segments.append(segment)  # Keep the Sinhala segment as is
        elif target_language == 'ta' and re.search('[\u0B80-\u0BFF]', segment):  # Check Tamil
            translated_segments.append(segment)  # Keep the Tamil segment as is
        elif target_language == 'en' and re.search('[a-zA-Z]', segment):  # Check English
            translated_segments.append(segment)  # Keep the English segment as is
        else:
            # Translate the segment to the target language
            translated = translator.translate(segment, src='auto', dest=target_language)
            translated_segments.append(translated.text)
    
    # Combine the translated segments back together
    return ''.join(translated_segments)

# Specify the target language: 'ta' for Tamil, 'en' for English, 'si' for Sinhala
target_language = 'si'  # Change to 'en' or 'si' as needed

# Translate the mixed input text
output_text = translate_mixed_text(input_text, target_language)

# Print the fully translated text
print(f"Translated Text: {output_text}")
# Out:
# Translated Text: ආයුබෝවන්මම දෙමළෙන් කතා කරනවානුචර එළිය

# %%
from googletrans import Translator
import re

# Initialize the Google Translator
translator = Translator()

# Input text with mixed languages
input_text = "Hello,நான் தமிழில் பேசுகிறேன்,නුචර එළිය"  # Mixed English, Tamil, and Sinhala

# Function to detect and translate the text
def translate_mixed_text(input_text, target_language):
    # Split the input text into segments, preserving spaces
    segments = re.split(r'(\s+|[,;.!?])', input_text)  # Split by spaces, punctuation, while keeping them as separate segments
    
    translated_segments = []
    
    for segment in segments:
        if not segment.strip():  # Preserve spaces and empty segments
            translated_segments.append(segment)
            continue
        
        if target_language == 'si' and re.search('[\u0D80-\u0DFF]', segment):  # Check Sinhala
            translated_segments.append(segment)  # Keep the Sinhala segment as is
        elif target_language == 'ta' and re.search('[\u0B80-\u0BFF]', segment):  # Check Tamil
            translated_segments.append(segment)  # Keep the Tamil segment as is
        elif target_language == 'en' and re.search('[a-zA-Z]', segment):  # Check English
            translated_segments.append(segment)  # Keep the English segment as is
        else:
            # Translate the segment to the target language
            translated = translator.translate(segment, src='auto', dest=target_language)
            translated_segments.append(translated.text)
    
    # Combine the translated segments back together
    return ''.join(translated_segments)

# Specify the target language: 'ta' for Tamil, 'en' for English, 'si' for Sinhala
target_language = 'ta'  # Change to 'en' or 'si' as needed

# Translate the mixed input text
output_text = translate_mixed_text(input_text, target_language)

# Print the fully translated text
print(f"Translated Text: {output_text}")
# Out:
# Translated Text: வணக்கம்அருவடிக்குநான் தமிழில் பேசுகிறேன்அருவடிக்குஆக்கிரமிப்பு ஒளி
